# %% [markdown]
# ## 1. Selecting Series Data

# %%
import numpy as np 
import pandas as pd

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
college.head(3)
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
# Amridge University                            1.0    291.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
city = college['CITY']
city.head()
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# University of Alabama in Huntsville    Huntsville
# Alabama State University               Montgomery
# Name: CITY, dtype: object

# %%
#iloc selects location using integer.
city.iloc[3] #returns a string
# Out:
# str

# %%
city.iloc[[0,1,2]] #returns a series
# Out:
# INSTNM
# Alabama A & M University                   Normal
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# Name: CITY, dtype: object

# %%
#selecting a subset of values with the slice notation
city.iloc[4:50:10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %%
#loc selections location using labels/strings.
city.loc['Alabama State University']
# Out:
# 'Montgomery'

# %%
np.random.seed(1)
labels = list(np.random.choice(city.index, 4))
labels
# Out:
# ['Northwest HVAC/R Training Center',
#  'California State University-Dominguez Hills',
#  'Lower Columbia College',
#  'Southwest Acupuncture College-Boulder']

# %%
#selection with loc indexer always includes the last element
city.loc['Alabama State University':'Reid State Technical College':10]
# Out:
# INSTNM
# Alabama State University              Montgomery
# Enterprise State Community College    Enterprise
# Heritage Christian University           Florence
# Marion Military Institute                 Marion
# Reid State Technical College           Evergreen
# Name: CITY, dtype: object

# %% [markdown]
# ## 2. Selecting DF Rows

# %%
college.iloc[[60, 99, 3]] 
#the same can be done with loc, but instead we pass the college names
# Out:
#                                             CITY STABBR  HBCU  MENONLY  \
# INSTNM
# University of Alaska Anchorage         Anchorage     AK   0.0      0.0
# International Academy of Hair Design       Tempe     AZ   0.0      0.0
# University of Alabama in Huntsville   Huntsville     AL   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# University of Alaska Anchorage              0.0         0       NaN       NaN
# International Academy of Hair Design        0.0         0       NaN       NaN
# University of Alabama in Huntsville         0.0         0     595.0     590.0
#
#                                       DISTANCEONLY     UGDS  \
# INSTNM
# University of Alaska Anchorage                 0.0  12865.0
# International Academy of Hair Design           0.0    188.0
# University of Alabama in Huntsville            0.0   5451.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
#slice notation using iloc on a DF. Notice that 
college.iloc[201:204]
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# American Film Institute Conservatory  Los Angeles     CA   0.0      0.0
# American Beauty College               West Covina     CA   0.0      0.0
# American Career College-Los Angeles   Los Angeles     CA   0.0      0.0
#
#                                       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# American Film Institute Conservatory        0.0         0       NaN       NaN
# American Beauty College                     0.0         0       NaN       NaN
# American Career College-Los Angeles         0.0         0       NaN       NaN
#
#                                       DISTANCEONLY    UGDS  \
# INSTNM
# American Film Institute Conservatory           0.0     NaN
# American Beauty College                        0.0    97.0
# American Career College-Los Angeles            0.0  1613.0
#
#                                              ...          UGDS_2MOR  UGDS_NRA  \
# ...

# %%
#also you can generate the labels for loc without having to copy and paste
college.iloc[[99, 20, 6]].index.tolist()
# Out:
# ['International Academy of Hair Design',
#  'George C Wallace State Community College-Hanceville',
#  'Central Alabama Community College']

# %% [markdown]
# ## 3. Selecting DF Rows and Columns simultaneously

# %%
#this is the basic format for iloc and loc
"""
df.iloc[rows, columns]
here rows/cols can be (: (all)),(slice of rows/cols),(list of rows/cols - contiguous and otherwise), 
                      (variables containing list of integers for rows and cols)

df.loc[rows, columns]
here rows/cols can be the same options as iloc, but using labels/strings instead of integers.
"""

# %%
#selecting a slice of rows and a single column
college.iloc[90:80:-2, 5]
#without specifying the step size, you would get an empty df as output
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %%
#replicating above result with loc
#stop uses the value at 81, since loc would include the value at 80 as well(being "end inclusive")
start = college.iloc[90].name
stop = college.iloc[81].name
college.loc[start:stop:-2, 'RELAFFIL']
# Out:
# INSTNM
# Empire Beauty School-Flagstaff     0
# Charles of Italy Beauty College    0
# Central Arizona College            0
# University of Arizona              0
# Arizona State University-Tempe     0
# Name: RELAFFIL, dtype: int64

# %% [markdown]
# ## 4. Selecting Data with both Integers and Labels

# %%
#this could be done previously through ix indexer,
#but has since been deprecated due to the confusion surrounding it
col_start = college.columns.get_loc('UGDS_WHITE')
col_stop = college.columns.get_loc('UGDS_UNKN') + 1
col_start, col_stop

#get_loc takes an index label and returns its integer location
# Out:
# (10, 19)

# %%
college.iloc[:5, col_start:col_stop]
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
#index[i] returns the label of the college at row i
row_start = college.index[10]
row_end = college.index[15]
college.loc[row_start:row_end, 'UGDS_WHITE':'UGDS_UNKN']
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# ...

# %%
#you COULD chain loc and iloc, but its generally a bad idea( i dont know why! )
college.iloc[10:16].loc[:, 'UGDS_WHITE':'UGDS_UNKN']
#this replicates the result obtained above
# Out:
#                                           UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Birmingham Southern College                   0.7983      0.1102     0.0195
# Chattahoochee Valley Community College        0.4661      0.4372     0.0492
# Concordia College Alabama                     0.0280      0.8758     0.0373
# South University-Montgomery                   0.3046      0.6054     0.0153
# Enterprise State Community College            0.6408      0.2435     0.0509
# James H Faulkner State Community College      0.6979      0.2259     0.0320
#
#                                           UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Birmingham Southern College                   0.0517     0.0102     0.0000
# Chattahoochee Valley Community College        0.0127     0.0023     0.0035
# Concordia College Alabama                     0.0093     0.0000     0.0000
# South University-Montgomery                   0.0153     0.0153     0.0096
# ...

# %% [markdown]
# ## 5. Speeding Up Scalar Selection

# %%
#valuable if computation is time is of utmost importance
"""
improved speeds with .iat and .at in comparison to 
.iloc and .loc in the context of scalar selection
"""

#lets time loc and at
# %timeit college.loc['Texas A & M University-College Station', 'UGDS_WHITE']
# Out:
# 10000 loops, best of 3: 48.2 µs per loop

# %%
#same result with at
# %timeit college.at['Texas A & M University-College Station', 'UGDS_WHITE']
# Out:
# 10000 loops, best of 3: 37.5 µs per loop

# %%
row_num = college.index.get_loc('Texas A & M University-College Station')
col_num = college.columns.get_loc('UGDS_WHITE')

# %%
# %timeit college.iloc[row_num, col_num]
# Out:
# 10000 loops, best of 3: 58.8 µs per loop

# %%
# %timeit college.iat[row_num, col_num]
# Out:
# 10000 loops, best of 3: 42.8 µs per loop

# %% [markdown]
# ## 6. Slicing Rows Lazily

# %%
#using indexing operator to lazily select rows. Its better to use iloc and loc to remain unambiguous
#df[start:[stop]:[step]]

# %% [markdown]
# ## 7. Slicing Rows Lexicographically

# %%
"""
loc lets you select all rows with an index lexicographically. 
Such a selection uses slice notation and works only if the index is sorted.
This is because the default behaviour of loc is select rows based on exact labels.
This behaviour is modified once the index col is sorted.
"""

college_sorted = college.sort_index()
college_sorted.head(3)
# Out:
#                                                 CITY STABBR  HBCU  MENONLY  \
# INSTNM
# A & W Healthcare Educators               New Orleans     LA   0.0      0.0
# A T Still University of Health Sciences   Kirksville     MO   0.0      0.0
# ABC Beauty Academy                           Garland     TX   0.0      0.0
#
#                                          WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# A & W Healthcare Educators                     0.0         0       NaN
# A T Still University of Health Sciences        0.0         0       NaN
# ABC Beauty Academy                             0.0         0       NaN
#
#                                          SATMTMID  DISTANCEONLY  UGDS  \
# INSTNM
# A & W Healthcare Educators                    NaN           0.0  40.0
# A T Still University of Health Sciences       NaN           0.0   NaN
# ABC Beauty Academy                            NaN           0.0  30.0
#
# ...

# %%
#lets choose all colleges that lexicographically occur between Sp and Su,(aka, passing the slice)
#notice that we don't have to pass in exact label names now...
college_sorted.loc['Sp':'Su'].head()
# Out:
#                                     CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# Spa Tech Institute-Ipswich       Ipswich     MA   0.0      0.0        0.0
# Spa Tech Institute-Plymouth     Plymouth     MA   0.0      0.0        0.0
# Spa Tech Institute-Westboro     Westboro     MA   0.0      0.0        0.0
# Spa Tech Institute-Westbrook   Westbrook     ME   0.0      0.0        0.0
# Spalding University           Louisville     KY   0.0      0.0        0.0
#
#                               RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Spa Tech Institute-Ipswich           0       NaN       NaN           0.0
# Spa Tech Institute-Plymouth          0       NaN       NaN           0.0
# Spa Tech Institute-Westboro          0       NaN       NaN           0.0
# Spa Tech Institute-Westbrook         0       NaN       NaN           0.0
# Spalding University                  1     490.0     440.0           0.0
#
# ...
